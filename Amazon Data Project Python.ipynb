# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\alexa\OneDrive\Documents\Careers\Freelance\Amazon Project\Amazon-orders.csv')
df.head()
# Out:
#   Order Date             Order ID  \
# 0  8/27/2019  112-7183488-5834633
# 1  8/27/2019  112-7183488-5834633
# 2  1/14/2020  112-6388508-8419469
# 3  1/21/2020  112-2583050-5347400
# 4   2/2/2020  111-6269212-4166636
#
#                        Payment Instrument Type     Website  \
# 0                            MasterCard - 6936  Amazon.com
# 1                            MasterCard - 6936  Amazon.com
# 2                            MasterCard - 8476  Amazon.com
# 3                            MasterCard - 8476  Amazon.com
# 4  MasterCard - 6936 and Gift Certificate/Card  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    NaN     alago@villanova.edu     8/27/2019
# 1                    NaN     alago@villanova.edu     8/28/2019
# 2                    NaN     alago@villanova.edu     1/14/2020
# 3                    NaN     alago@villanova.edu     1/21/2020
# 4                    NaN     alago@villanova.edu      2/2/2020
#
#   Shipping Address Name         Shipping Address Street 1  \
# 0           Athena Lago  VU BOX 8545 VILLANOVA UNIVERSITY
# 1           Athena Lago  VU BOX 8545 VILLANOVA UNIVERSITY
# 2           Athena Lago  VU BOX 8545 VILLANOVA UNIVERSITY
# 3           Athena Lago  VU BOX 8545 VILLANOVA UNIVERSITY
# 4           Athena Lago                   25 COOLIDGE AVE
#
#   Shipping Address Street 2  ... Order Status Carrier Name & Tracking Number  \
# 0       800 E LANCASTER AVE  ...      Shipped        UPS(1Z21F58E0378257234)
# 1       800 E LANCASTER AVE  ...      Shipped       AMZN_US(TBA747033167000)
# 2       800 E LANCASTER AVE  ...      Shipped       AMZN_US(TBA671170261000)
# 3       800 E LANCASTER AVE  ...      Shipped       AMZN_US(TBAACY503012255)
# 4                       NaN  ...      Shipped   USPS(9341989714090419647195)
#
#   Subtotal Shipping Charge Tax Before Promotions Total Promotions Tax Charged  \
# 0  $57.75           $0.00                 $3.46            $0.00       $3.46
# 1  $43.49           $0.00                 $2.61            $0.00       $2.61
# 2   $8.99           $0.00                 $0.54            $0.00       $0.54
# 3  $17.16           $0.00                 $1.03            $0.00       $1.03
# 4  $12.49           $0.00                 $0.83            $0.00       $0.83
#
#   Total Charged   Buyer Name Group Name
# 0       $61.21   Athena Lago        NaN
# 1       $46.10   Athena Lago        NaN
# 2        $9.53   Athena Lago        NaN
# 3       $18.19   Athena Lago        NaN
# 4       $13.32   Athena Lago        NaN
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (57, 23)

# %%
df = df.fillna(0)
df.head()
# Out:
#   Order Date             Order ID  \
# 0  8/27/2019  112-7183488-5834633
# 1  8/27/2019  112-7183488-5834633
# 2  1/14/2020  112-6388508-8419469
# 3  1/21/2020  112-2583050-5347400
# 4   2/2/2020  111-6269212-4166636
#
#                        Payment Instrument Type     Website  \
# 0                            MasterCard - 6936  Amazon.com
# 1                            MasterCard - 6936  Amazon.com
# 2                            MasterCard - 8476  Amazon.com
# 3                            MasterCard - 8476  Amazon.com
# 4  MasterCard - 6936 and Gift Certificate/Card  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0     alago@villanova.edu     8/27/2019
# 1                    0.0     alago@villanova.edu     8/28/2019
# 2                    0.0     alago@villanova.edu     1/14/2020
# 3                    0.0     alago@villanova.edu     1/21/2020
# 4                    0.0     alago@villanova.edu      2/2/2020
#
#   Shipping Address Name         Shipping Address Street 1  \
# 0           Athena Lago  VU BOX 8545 VILLANOVA UNIVERSITY
# 1           Athena Lago  VU BOX 8545 VILLANOVA UNIVERSITY
# 2           Athena Lago  VU BOX 8545 VILLANOVA UNIVERSITY
# 3           Athena Lago  VU BOX 8545 VILLANOVA UNIVERSITY
# 4           Athena Lago                   25 COOLIDGE AVE
#
#   Shipping Address Street 2  ... Order Status Carrier Name & Tracking Number  \
# 0       800 E LANCASTER AVE  ...      Shipped        UPS(1Z21F58E0378257234)
# 1       800 E LANCASTER AVE  ...      Shipped       AMZN_US(TBA747033167000)
# 2       800 E LANCASTER AVE  ...      Shipped       AMZN_US(TBA671170261000)
# 3       800 E LANCASTER AVE  ...      Shipped       AMZN_US(TBAACY503012255)
# 4                         0  ...      Shipped   USPS(9341989714090419647195)
#
#   Subtotal Shipping Charge Tax Before Promotions Total Promotions Tax Charged  \
# 0  $57.75           $0.00                 $3.46            $0.00       $3.46
# 1  $43.49           $0.00                 $2.61            $0.00       $2.61
# 2   $8.99           $0.00                 $0.54            $0.00       $0.54
# 3  $17.16           $0.00                 $1.03            $0.00       $1.03
# 4  $12.49           $0.00                 $0.83            $0.00       $0.83
#
#   Total Charged   Buyer Name Group Name
# 0       $61.21   Athena Lago        0.0
# 1       $46.10   Athena Lago        0.0
# 2        $9.53   Athena Lago        0.0
# 3       $18.19   Athena Lago        0.0
# 4       $13.32   Athena Lago        0.0
#
# [5 rows x 23 columns]

# %%
df["Total Charged"] = df["Total Charged"].str.replace('$','').astype(float)
df.head()
# Out:
# <ipython-input-15-8608fa0e0747>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df["Total Charged"] = df["Total Charged"].str.replace('$','').astype(float)
#   Order Date             Order ID  \
# 0  8/27/2019  112-7183488-5834633
# 1  8/27/2019  112-7183488-5834633
# 2  1/14/2020  112-6388508-8419469
# 3  1/21/2020  112-2583050-5347400
# 4   2/2/2020  111-6269212-4166636
#
#                        Payment Instrument Type     Website  \
# 0                            MasterCard - 6936  Amazon.com
# 1                            MasterCard - 6936  Amazon.com
# 2                            MasterCard - 8476  Amazon.com
# 3                            MasterCard - 8476  Amazon.com
# 4  MasterCard - 6936 and Gift Certificate/Card  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0     alago@villanova.edu     8/27/2019
# 1                    0.0     alago@villanova.edu     8/28/2019
# 2                    0.0     alago@villanova.edu     1/14/2020
# 3                    0.0     alago@villanova.edu     1/21/2020
# 4                    0.0     alago@villanova.edu      2/2/2020
#
#   Shipping Address Name         Shipping Address Street 1  \
# 0           Athena Lago  VU BOX 8545 VILLANOVA UNIVERSITY
# 1           Athena Lago  VU BOX 8545 VILLANOVA UNIVERSITY
# 2           Athena Lago  VU BOX 8545 VILLANOVA UNIVERSITY
# 3           Athena Lago  VU BOX 8545 VILLANOVA UNIVERSITY
# 4           Athena Lago                   25 COOLIDGE AVE
#
#   Shipping Address Street 2  ... Order Status Carrier Name & Tracking Number  \
# 0       800 E LANCASTER AVE  ...      Shipped        UPS(1Z21F58E0378257234)
# 1       800 E LANCASTER AVE  ...      Shipped       AMZN_US(TBA747033167000)
# 2       800 E LANCASTER AVE  ...      Shipped       AMZN_US(TBA671170261000)
# 3       800 E LANCASTER AVE  ...      Shipped       AMZN_US(TBAACY503012255)
# 4                         0  ...      Shipped   USPS(9341989714090419647195)
#
#   Subtotal Shipping Charge Tax Before Promotions Total Promotions Tax Charged  \
# 0  $57.75           $0.00                 $3.46            $0.00       $3.46
# 1  $43.49           $0.00                 $2.61            $0.00       $2.61
# 2   $8.99           $0.00                 $0.54            $0.00       $0.54
# 3  $17.16           $0.00                 $1.03            $0.00       $1.03
# 4  $12.49           $0.00                 $0.83            $0.00       $0.83
#
#   Total Charged   Buyer Name Group Name
# 0         61.21  Athena Lago        0.0
# 1         46.10  Athena Lago        0.0
# 2          9.53  Athena Lago        0.0
# 3         18.19  Athena Lago        0.0
# 4         13.32  Athena Lago        0.0
#
# [5 rows x 23 columns]

# %%
df["Total Charged"].sum()
# Out:
# 1603.98

# %%
df["Total Charged"].mean()
# Out:
# 28.140000000000004

# %%
df["Total Charged"].median()
# Out:
# 17.99

# %%
df["Total Charged"].max()
# Out:
# 95.09

# %%
df["Total Charged"].min()
# Out:
# 5.29

# %%
df["Tax Charged"] = df["Tax Charged"].str.replace('$','').astype(float)

df.head()
# Out:
# <ipython-input-22-0147bda9d2ad>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df["Tax Charged"] = df["Tax Charged"].str.replace('$','').astype(float)
#   Order Date             Order ID  \
# 0  8/27/2019  112-7183488-5834633
# 1  8/27/2019  112-7183488-5834633
# 2  1/14/2020  112-6388508-8419469
# 3  1/21/2020  112-2583050-5347400
# 4   2/2/2020  111-6269212-4166636
#
#                        Payment Instrument Type     Website  \
# 0                            MasterCard - 6936  Amazon.com
# 1                            MasterCard - 6936  Amazon.com
# 2                            MasterCard - 8476  Amazon.com
# 3                            MasterCard - 8476  Amazon.com
# 4  MasterCard - 6936 and Gift Certificate/Card  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0     alago@villanova.edu     8/27/2019
# 1                    0.0     alago@villanova.edu     8/28/2019
# 2                    0.0     alago@villanova.edu     1/14/2020
# 3                    0.0     alago@villanova.edu     1/21/2020
# 4                    0.0     alago@villanova.edu      2/2/2020
#
#   Shipping Address Name         Shipping Address Street 1  \
# 0           Athena Lago  VU BOX 8545 VILLANOVA UNIVERSITY
# 1           Athena Lago  VU BOX 8545 VILLANOVA UNIVERSITY
# 2           Athena Lago  VU BOX 8545 VILLANOVA UNIVERSITY
# 3           Athena Lago  VU BOX 8545 VILLANOVA UNIVERSITY
# 4           Athena Lago                   25 COOLIDGE AVE
#
#   Shipping Address Street 2  ... Order Status Carrier Name & Tracking Number  \
# 0       800 E LANCASTER AVE  ...      Shipped        UPS(1Z21F58E0378257234)
# 1       800 E LANCASTER AVE  ...      Shipped       AMZN_US(TBA747033167000)
# 2       800 E LANCASTER AVE  ...      Shipped       AMZN_US(TBA671170261000)
# 3       800 E LANCASTER AVE  ...      Shipped       AMZN_US(TBAACY503012255)
# 4                         0  ...      Shipped   USPS(9341989714090419647195)
#
#   Subtotal Shipping Charge Tax Before Promotions Total Promotions Tax Charged  \
# 0  $57.75           $0.00                 $3.46            $0.00         3.46
# 1  $43.49           $0.00                 $2.61            $0.00         2.61
# 2   $8.99           $0.00                 $0.54            $0.00         0.54
# 3  $17.16           $0.00                 $1.03            $0.00         1.03
# 4  $12.49           $0.00                 $0.83            $0.00         0.83
#
#   Total Charged   Buyer Name  Group Name
# 0         61.21  Athena Lago         0.0
# 1         46.10  Athena Lago         0.0
# 2          9.53  Athena Lago         0.0
# 3         18.19  Athena Lago         0.0
# 4         13.32  Athena Lago         0.0
#
# [5 rows x 23 columns]

# %%
df["Tax Charged"].sum()
# Out:
# 70.64

# %%
df["Tax Charged"].sum()/df["Total Charged"].sum()
# Out:
# 0.044040449382161874
